# %%
# !nvidia-smi
# Out:
# Thu Apr 10 00:37:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip3 uninstall wandb -y
# Out:
# Found existing installation: wandb 0.19.1
# Uninstalling wandb-0.19.1:
#   Successfully uninstalled wandb-0.19.1

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working

# %%
# !mkdir datasets
# %cd datasets

# !pip install certifi cycler roboflow --quiet

from roboflow import Roboflow

# rf = Roboflow(api_key="2WNjuUXs8KiBRhS50vWQ")
# project = rf.workspace("university-bswxt").project("crack-bphdr")
# version = project.version(2)
# dataset = version.download("yolov8-obb")

rf = Roboflow(api_key="2WNjuUXs8KiBRhS50vWQ")
project = rf.workspace("university-bswxt").project("crack-bphdr")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# /kaggle/working/datasets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 68.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to crack-2 in yolov8:: 100%|██████████| 8070/8070 [00:00<00:00, 8762.64it/s]

# %%
# %cd /{HOME}
# Out:
# /kaggle/working

# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 55488, done.
# remote: Counting objects: 100% (1023/1023), done.
# remote: Compressing objects: 100% (533/533), done.
# remote: Total 55488 (delta 797), reused 490 (delta 490), pack-reused 54465 (from 4)
# Receiving objects: 100% (55488/55488), 31.36 MiB | 29.68 MiB/s, done.
# Resolving deltas: 100% (40924/40924), done.

# %%
# %cd /{HOME}/ultralytics
# Out:
# /kaggle/working/ultralytics

# %%
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.105-0.editable-py3-none-any.whl size=23150 sha256=7e8e398e032bea085db338b34f83df16a543c8701dd3d53a2ea98ff73d530094
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_2vfh2h8/wheels/1b/eb/7d/853f2df0532389050170c8cd117b40e1fef8d125854a910fe6
# Successfully built ultralytics
# ...

# %%
import yaml

# Define the new content
new_content = {
   "path": "/kaggle/working/datasets/crack-2",

"train": "train/images",
   "test":"test/images",
"val": "test/images",

"names":['crack'],
  "0": "Crack"
}

# Load the existing YAML file
with open('/kaggle/working/datasets/crack-2/data.yaml', 'r') as file:
    data = yaml.safe_load(file)

# Update the data with the new content
data.update(new_content)

# Write the updated data back to the YAML file
with open('/kaggle/working/datasets/crack-2/data.yaml', 'w') as file:
    yaml.dump(data, file)

# %%
# !yolo detect train model=yolov10s.yaml data=/kaggle/working/datasets/crack-2/data.yaml epochs=100 imgsz=640 optimizer="SGD"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.105 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r /kaggle/working/yolov10s_SGD.zip /kaggle/working/ultralytics/runs/detect
# Out:
#   adding: kaggle/working/ultralytics/runs/detect/ (stored 0%)
#   adding: kaggle/working/ultralytics/runs/detect/train/ (stored 0%)
#   adding: kaggle/working/ultralytics/runs/detect/train/confusion_matrix_normalized.png (deflated 38%)
#   adding: kaggle/working/ultralytics/runs/detect/train/val_batch2_labels.jpg (deflated 7%)
#   adding: kaggle/working/ultralytics/runs/detect/train/events.out.tfevents.1744245515.883a662c9f48.71.0 (deflated 90%)
#   adding: kaggle/working/ultralytics/runs/detect/train/labels_correlogram.jpg (deflated 38%)
#   adding: kaggle/working/ultralytics/runs/detect/train/args.yaml (deflated 52%)
#   adding: kaggle/working/ultralytics/runs/detect/train/val_batch1_labels.jpg (deflated 6%)
#   adding: kaggle/working/ultralytics/runs/detect/train/R_curve.png (deflated 16%)
#   adding: kaggle/working/ultralytics/runs/detect/train/val_batch1_pred.jpg (deflated 6%)
#   adding: kaggle/working/ultralytics/runs/detect/train/train_batch0.jpg (deflated 3%)
# ...
